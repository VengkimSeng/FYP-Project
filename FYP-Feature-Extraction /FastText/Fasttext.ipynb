# %%
# FastText Feature Extraction with Enhanced Visualization and External Feature Storage

import os
import sys
import subprocess
import numpy as np
import pandas as pd
import pickle
from gensim.models.fasttext import load_facebook_vectors
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import gzip
import shutil
import json

# 1. Install required packages if missing
def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

required = ["gensim", "numpy", "pandas", "matplotlib", "scikit-learn"]
for pkg in required:
    try:
        __import__(pkg if pkg != "scikit-learn" else "sklearn")
    except ImportError:
        install(pkg)

# 2. Paths and filenames
MODEL_PATH = 'cc.km.300.bin'
MODEL_GZ_PATH = 'cc.km.300.bin.gz'
FASTTEXT_URL = "https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.km.300.bin.gz"
METADATA_PATH = '../../orginal_articles/metadata.csv'
TEXT_DIR = '/Users/socheata/Documents/FYP-Khmer-Classification/Preprocess_articles'

# Output directory for FastText features (outside code dir)
FASTTEXT_FEATURE_DIR = '/Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features'
os.makedirs(FASTTEXT_FEATURE_DIR, exist_ok=True)
EMBEDDINGS_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'embeddings.npy')
LABELS_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'labels.npy')
DOCIDS_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'doc_ids.npy')
WORD_EMBEDDINGS_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'word_embeddings_per_doc.pkl')
TSNE_PLOT_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'khmer_embeddings.png')
EMBEDDING_DIST_PLOT_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'embedding_value_distribution.png')
DOC_TSNE_PLOT_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'document_tsne_by_category.png')
EMBEDDING_NORMS_PLOT_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'embedding_norms.png')
WORD_EMBEDDINGS_TSNE_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'word_embeddings_tsne.png')
WORD_EMBEDDINGS_JSON_PATH = os.path.join(FASTTEXT_FEATURE_DIR, 'word_embeddings.json')

# 3. Load metadata
try:
    metadata = pd.read_csv(METADATA_PATH)
except Exception as e:
    print(f"Error loading metadata: {e}")
    sys.exit(1)
required_cols = {'docId', 'category', 'wordCount'}
if not required_cols.issubset(metadata.columns):
    print(f"Metadata missing required columns: {required_cols}")
    sys.exit(1)

# 4. Use local FastText model files if present
if not os.path.exists(MODEL_PATH):
    if not os.path.exists(MODEL_GZ_PATH):
        raise FileNotFoundError(f"Required FastText model files not found: {MODEL_PATH} or {MODEL_GZ_PATH}")
    print(f"Extracting {MODEL_GZ_PATH} ...")
    with gzip.open(MODEL_GZ_PATH, 'rb') as f_in, open(MODEL_PATH, 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
    print(f"Extracted to {MODEL_PATH}")

# 5. Load pretrained FastText model
try:
    model = load_facebook_vectors(MODEL_PATH)
except Exception as e:
    print(f"Error loading FastText model: {e}")
    sys.exit(1)

# 6. Function to compute document embedding
def compute_doc_embedding(tokens, model, verbose=False):
    vectors = []
    missing_words = []
    for w in tokens:
        try:
            vector = model.get_vector(w)
            vectors.append(vector)
            if verbose:
                print(f"Word: {w} -> Vector: {vector[:5]}...")  # Show first 5 dimensions
        except KeyError:
            vectors.append(np.zeros(model.vector_size))
            missing_words.append(w)
    if not vectors:
        return np.zeros(model.vector_size)
    if verbose:
        print(f"\nSummary:")
        print(f"Total tokens: {len(tokens)}")
        print(f"Tokens with embeddings: {len(tokens) - len(missing_words)}")
        print(f"Tokens missing embeddings: {len(missing_words)}")
        if missing_words:
            print(f"Missing words (first 10): {missing_words[:10]}")
    return np.mean(vectors, axis=0)

# 7. Visualize word embeddings using t-SNE
def visualize_word_embeddings(tokens, model, output_path):
    word_vectors = []
    valid_tokens = []
    for w in tokens:
        try:
            word_vectors.append(model.get_vector(w))
            valid_tokens.append(w)
        except KeyError:
            continue
    if not word_vectors:
        print("No valid word embeddings found for visualization.")
        return
    word_vectors = np.array(word_vectors)
    tsne = TSNE(n_components=2, random_state=42, perplexity=5)
    word_tsne = tsne.fit_transform(word_vectors)
    plt.figure(figsize=(12, 8))
    plt.scatter(word_tsne[:, 0], word_tsne[:, 1], alpha=0.7)
    for i, word in enumerate(valid_tokens):
        plt.annotate(word, (word_tsne[i, 0], word_tsne[i, 1]), fontsize=9)
    plt.title("t-SNE Visualization of Word Embeddings")
    plt.xlabel("t-SNE 1")
    plt.ylabel("t-SNE 2")
    plt.tight_layout()
    plt.savefig(output_path)
    plt.close()
    print(f"Word embeddings visualization saved to {output_path}")

# 8. Analyze embedding norms
def plot_embedding_norms(tokens, model, output_path):
    norms = []
    for w in tokens:
        try:
            norm = np.linalg.norm(model.get_vector(w))
            norms.append(norm)
        except KeyError:
            continue
    if not norms:
        print("No valid word embeddings found for norm analysis.")
        return
    plt.figure(figsize=(10, 6))
    plt.hist(norms, bins=30, alpha=0.7, color='blue', edgecolor='black')
    plt.title("Distribution of Word Embedding Norms")
    plt.xlabel("Norm")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.savefig(output_path)
    plt.close()
    print(f"Embedding norms plot saved to {output_path}")

# 9. Save word embeddings to JSON
def save_word_embeddings(tokens, model, output_path):
    word_embeddings = {}
    for w in tokens:
        try:
            word_embeddings[w] = model.get_vector(w).tolist()
        except KeyError:
            word_embeddings[w] = None
    with open(output_path, 'w') as f:
        json.dump(word_embeddings, f, indent=4)
    print(f"Word embeddings saved to {output_path}")

# For demonstration, process the first document
first_doc_id = metadata.iloc[0]['docId']
first_text_path = os.path.join(TEXT_DIR, f"{first_doc_id}.txt")
if os.path.exists(first_text_path):
    with open(first_text_path, 'r', encoding='utf-8') as f:
        sample_words = f.read().split()
    print(f"\nDetails for first document ({first_doc_id}):")
    _ = compute_doc_embedding(sample_words, model, verbose=True)
    visualize_word_embeddings(sample_words, model, WORD_EMBEDDINGS_TSNE_PATH)
    plot_embedding_norms(sample_words, model, EMBEDDING_NORMS_PLOT_PATH)
    save_word_embeddings(sample_words, model, WORD_EMBEDDINGS_JSON_PATH)
else:
    sample_words = []
    print(f"\nFirst document file not found: {first_text_path}")

# 10. Read tokenized text files, compute embeddings, and collect word embeddings for all docs
doc_embeddings = []
labels = []
doc_ids = []
word_embeddings_per_doc = {}

for idx, row in metadata.iterrows():
    doc_id = row['docId']
    category = row['category']
    text_path = os.path.join(TEXT_DIR, f"{doc_id}.txt")
    if not os.path.exists(text_path):
        print(f"Warning: File {text_path} not found, skipping.")
        continue
    try:
        with open(text_path, 'r', encoding='utf-8') as f:
            tokens = f.read().split()
    except Exception as e:
        print(f"Error reading {text_path}: {e}")
        continue
    emb = compute_doc_embedding(tokens, model)
    doc_embeddings.append(emb)
    labels.append(category)
    doc_ids.append(doc_id)
    # Collect word embeddings for this document
    word_embeddings = {}
    for word in tokens:
        try:
            word_embeddings[word] = model.get_vector(word)
        except KeyError:
            word_embeddings[word] = np.zeros(model.vector_size)
    word_embeddings_per_doc[doc_id] = word_embeddings

doc_embeddings = np.array(doc_embeddings)
labels = np.array(labels)
doc_ids = np.array(doc_ids)
print(f"\nLoaded {len(doc_embeddings)} documents with embeddings.")

# 11. Print all words from the first document
print("\nAll words from the first document:")
print(sample_words)

# 12. t-SNE of all document embeddings, colored by category
le = LabelEncoder()
label_ids = le.fit_transform(labels)
tsne = TSNE(n_components=2, random_state=42, perplexity=5)
doc_tsne = tsne.fit_transform(doc_embeddings)
plt.figure(figsize=(10, 8))
scatter = plt.scatter(doc_tsne[:, 0], doc_tsne[:, 1], c=label_ids, cmap='tab10', alpha=0.7)
plt.title("t-SNE of Document Embeddings by Category")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
handles, _ = scatter.legend_elements()
plt.legend(handles, le.classes_, title="Category")
plt.tight_layout()
plt.savefig(DOC_TSNE_PLOT_PATH)
plt.close()
print("Saved:", DOC_TSNE_PLOT_PATH)

# 13. Save document embeddings, labels, doc_ids, and word embeddings per doc
np.save(EMBEDDINGS_PATH, doc_embeddings)
np.save(LABELS_PATH, labels)
np.save(DOCIDS_PATH, doc_ids)
with open(WORD_EMBEDDINGS_PATH, 'wb') as f:
    pickle.dump(word_embeddings_per_doc, f)
print(f"\nDocument embeddings saved to {EMBEDDINGS_PATH}")
print(f"Labels saved to {LABELS_PATH}")
print(f"Document IDs saved to {DOCIDS_PATH}")
print(f"Word embeddings per document saved to {WORD_EMBEDDINGS_PATH}")
# Out:
# /Users/socheata/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Details for first document (health1):
# Word: ប្រហែស -> Vector: [-0.03345599  0.05267933  0.04053002  0.08429828  0.00405834]...
# Word: ធ្វើឲ្យ -> Vector: [-0.00600505 -0.0061434   0.02829137  0.00874665  0.03501422]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: គ្រោះថ្នាក់ -> Vector: [ 0.00820211  0.03495497 -0.00070203  0.01174884 -0.02036592]...
# Word: ឆ្លង -> Vector: [ 0.03519922 -0.00709001  0.00515401  0.10655373 -0.08541018]...
# Word: រាលដាល -> Vector: [-0.07181112 -0.02998904 -0.10582854  0.04541619 -0.06229345]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: កំណើន -> Vector: [0.05983778 0.04880498 0.04236346 0.03764829 0.03964679]...
# Word: ការរកឃើញ -> Vector: [ 0.01063065 -0.01037034  0.00764738  0.01192325 -0.00881259]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: ខែកក្កដា -> Vector: [ 0.01173213 -0.01793897  0.01305536  0.00960362  0.02135866]...
# Word: កន្លងមក -> Vector: [-0.00621254 -0.03728534 -0.01033871 -0.01030543  0.00699494]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: ធ្វើឲ្យ -> Vector: [-0.00600505 -0.0061434   0.02829137  0.00874665  0.03501422]...
# Word: ការព្រួយបារម្ភ -> Vector: [ 0.00034846  0.00595834  0.01187229  0.00984057 -0.01089586]...
# Word: ខ្លាំង -> Vector: [0.00135131 0.00682149 0.00612685 0.02931699 0.02089163]...
# Word: លទ្ធភាព -> Vector: [-0.00808417  0.04743794 -0.02375636  0.06156838 -0.02558208]...
# Word: អាចនឹង -> Vector: [-0.00245684 -0.02277157 -0.01430559  0.02505141 -0.01870622]...
# Word: ការរាលដាល -> Vector: [-0.00240573 -0.00833084 -0.02312067  0.05133001 -0.02554387]...
# Word: ជា -> Vector: [ 0.0429856  -0.14815898  0.01771417 -0.02862751  0.01380449]...
# Word: សហគមន៍ -> Vector: [ 0.0232792  -0.02307178  0.00730944 -0.02068416 -0.00277588]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: ប្រទេស -> Vector: [ 0.0133411   0.01293716  0.00663447 -0.04537583 -0.01400372]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: មកដល់ -> Vector: [ 0.00845311  0.00364513 -0.0147155  -0.0023592   0.03743618]...
# Word: ពេលនេះ -> Vector: [-0.02732893  0.01565723  0.00714204 -0.03121809 -0.04175714]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: កើតមាន -> Vector: [ 7.1050228e-05  9.1458000e-03  3.2479323e-02 -2.8801609e-02
#  -9.1056554e-03]...
# Word: ក្រសូង -> Vector: [ 0.01279786 -0.00241436 -0.00507723 -0.00743497  0.00485966]...
# Word: សុខាភិបាល -> Vector: [ 0.00548316 -0.00160399 -0.04230862  0.01563833 -0.00720036]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: ព្រមាន -> Vector: [-0.01156406  0.0396596   0.00318825  0.07709006 -0.00110067]...
# Word: ការរាលដាល -> Vector: [-0.00240573 -0.00833084 -0.02312067  0.05133001 -0.02554387]...
# Word: ជា -> Vector: [ 0.0429856  -0.14815898  0.01771417 -0.02862751  0.01380449]...
# Word: សហគមន៍ -> Vector: [ 0.0232792  -0.02307178  0.00730944 -0.02068416 -0.00277588]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: ប្រាកដ -> Vector: [ 0.03604876 -0.0200538   0.01159198  0.02804219 -0.00066738]...
# Word: ជា -> Vector: [ 0.0429856  -0.14815898  0.01771417 -0.02862751  0.01380449]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: កើតមាន -> Vector: [ 7.1050228e-05  9.1458000e-03  3.2479323e-02 -2.8801609e-02
#  -9.1056554e-03]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: ប្រទេស -> Vector: [ 0.0133411   0.01293716  0.00663447 -0.04537583 -0.01400372]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: ជំរុញ -> Vector: [ 0.01505005  0.03892946 -0.05451905  0.03842826  0.00128272]...
# Word: ឲ្យ -> Vector: [-0.01355013 -0.01519408 -0.00186673  0.02926468 -0.00065203]...
# Word: ប្រជាជន -> Vector: [ 0.00974695 -0.00742508 -0.00670336 -0.05192851 -0.00032723]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: បង្កើន -> Vector: [ 0.00283028  0.02800567 -0.0008339   0.03020064  0.0057412 ]...
# Word: ការប្រុងប្រយ័ត្ន -> Vector: [ 0.00758382 -0.00714755 -0.0070307   0.02813825  0.00979023]...
# Word: ពិសេស -> Vector: [-0.01978645  0.00213997  0.01512976 -0.00082994 -0.04350616]...
# Word: ឈប់ -> Vector: [-0.118195   -0.08593461  0.05081753  0.0116917   0.04997361]...
# Word: សម្រាក -> Vector: [-0.0293004   0.03253084  0.02154524  0.03582994  0.04038845]...
# Word: រយៈពេល -> Vector: [-0.00354148  0.02862719  0.01408264  0.00471839  0.00655422]...
# Word: ប្រាំ -> Vector: [ 0.01332883  0.03423471 -0.08368123 -0.0491695   0.00185968]...
# Word: ថ្ងៃ -> Vector: [ 0.00425566 -0.0162357  -0.00135446  0.00474433 -0.01356429]...
# Word: ថ្ងៃទី -> Vector: [ 0.036052    0.00134358  0.01997465 -0.01750254 -0.0384452 ]...
# Word: ខែសីហា -> Vector: [-0.01383933 -0.00347107  0.01652075  0.04917513  0.04534669]...
# Word: គិត -> Vector: [-0.03420072 -0.13105711  0.06048586  0.06789787 -0.02675577]...
# Word: ប្រជាជន -> Vector: [ 0.00974695 -0.00742508 -0.00670336 -0.05192851 -0.00032723]...
# Word: ជាច្រើន -> Vector: [-0.00561647 -0.00525619 -0.01304061 -0.04688359  0.00115179]...
# Word: ធ្វើដំណើរកម្សាន្ត -> Vector: [ 0.01950105 -0.0070612   0.00583783  0.01800166 -0.00997894]...
# Word: ក្នុង -> Vector: [ 0.00331758 -0.03540234 -0.0066963  -0.00322061 -0.00039702]...
# Word: ប្រទេស -> Vector: [ 0.0133411   0.01293716  0.00663447 -0.04537583 -0.01400372]...
# Word: ការព្រួយបារម្ភ -> Vector: [ 0.00034846  0.00595834  0.01187229  0.00984057 -0.01089586]...
# Word: លទ្ធភាព -> Vector: [-0.00808417  0.04743794 -0.02375636  0.06156838 -0.02558208]...
# Word: ការរាលដាល -> Vector: [-0.00240573 -0.00833084 -0.02312067  0.05133001 -0.02554387]...
# Word: ជា -> Vector: [ 0.0429856  -0.14815898  0.01771417 -0.02862751  0.01380449]...
# Word: សហគមន៍ -> Vector: [ 0.0232792  -0.02307178  0.00730944 -0.02068416 -0.00277588]...
# Word: កើតមាន -> Vector: [ 7.1050228e-05  9.1458000e-03  3.2479323e-02 -2.8801609e-02
#  -9.1056554e-03]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: ផ្ទុក -> Vector: [0.09193765 0.05465265 0.04010325 0.14360154 0.00922115]...
# Word: មេរោគ -> Vector: [ 0.07845636 -0.01444783  0.00146271  0.10039832 -0.08200911]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: រកឃើញ -> Vector: [ 0.00870357 -0.01067508  0.00607973  0.01969118 -0.02038949]...
# Word: កើនឡើង -> Vector: [ 0.05461271  0.02278532 -0.00942868 -0.01021447  0.04575335]...
# Word: នាក់ -> Vector: [ 0.04856071  0.02234742 -0.02915826 -0.0263737  -0.0197516 ]...
# Word: កត្តា -> Vector: [ 0.02031308 -0.02933812 -0.08689989  0.04491511  0.00763751]...
# Word: នាំ -> Vector: [-0.04404604  0.0195121  -0.02746391 -0.02326749 -0.00081846]...
# Word: ការរាលដាល -> Vector: [-0.00240573 -0.00833084 -0.02312067  0.05133001 -0.02554387]...
# Word: ជា -> Vector: [ 0.0429856  -0.14815898  0.01771417 -0.02862751  0.01380449]...
# Word: សហគមន៍ -> Vector: [ 0.0232792  -0.02307178  0.00730944 -0.02068416 -0.00277588]...
# Word: រហូតម -> Vector: [ 0.00667805  0.02540026  0.01897868  0.00820856 -0.01757309]...
# Word: ពេលនេះ -> Vector: [-0.02732893  0.01565723  0.00714204 -0.03121809 -0.04175714]...
# Word: ប្រាកដ -> Vector: [ 0.03604876 -0.0200538   0.01159198  0.02804219 -0.00066738]...
# Word: ករណី -> Vector: [-0.05647295  0.01683438 -0.0265009  -0.00170022 -0.05695137]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: ទាក់ទង -> Vector: [-0.01002299 -0.01684374 -0.01677559  0.00609752  0.02222923]...
# Word: ការនាំចូល -> Vector: [-0.01667419  0.00779073 -0.04114362  0.00612358  0.03843555]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: បើក -> Vector: [-0.06939386  0.07253652 -0.03937708  0.1086455  -0.12652998]...
# Word: ការហោះហើរ -> Vector: [-0.03427208 -0.01526417  0.01484929 -0.00361167 -0.00145026]...
# Word: ទូលាយ -> Vector: [-0.09851445  0.00449706 -0.0311413   0.05303442 -0.01143225]...
# Word: ចូល -> Vector: [-0.02848471  0.01358267  0.02468962  0.0002034   0.06798841]...
# Word: ប្រទេស -> Vector: [ 0.0133411   0.01293716  0.00663447 -0.04537583 -0.01400372]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: សេដ្ឋកិច្ច -> Vector: [ 0.00053268  0.00011328 -0.00566679  0.00444828  0.00533278]...
# Word: កត្តា -> Vector: [ 0.02031308 -0.02933812 -0.08689989  0.04491511  0.00763751]...
# Word: គួរឲ្យ -> Vector: [-0.00311633 -0.02303686 -0.01878188  0.0141191  -0.00618377]...
# Word: ព្រួយបារម្ភ -> Vector: [ 0.0060263   0.01658344  0.01017941  0.02421996 -0.01035092]...
# Word: ករណី -> Vector: [-0.05647295  0.01683438 -0.0265009  -0.00170022 -0.05695137]...
# Word: កើតមាន -> Vector: [ 7.1050228e-05  9.1458000e-03  3.2479323e-02 -2.8801609e-02
#  -9.1056554e-03]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: ផ្ទុក -> Vector: [0.09193765 0.05465265 0.04010325 0.14360154 0.00922115]...
# Word: មេរោគ -> Vector: [ 0.07845636 -0.01444783  0.00146271  0.10039832 -0.08200911]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: មកដល់ -> Vector: [ 0.00845311  0.00364513 -0.0147155  -0.0023592   0.03743618]...
# Word: ព្រលានយន្តហោះ -> Vector: [-0.00238097 -0.00356162  0.0084822   0.02480515 -0.00695193]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: ធ្វើតេស្ត -> Vector: [ 0.01574994 -0.05237399 -0.00872604  0.02760162 -0.01788941]...
# Word: ប៉ុន្តែ -> Vector: [-0.00904474 -0.01252226 -0.00302819 -0.02101588  0.01572545]...
# Word: រក -> Vector: [ 0.07616003 -0.05559717 -0.03931954 -0.06337111  0.13935758]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: ឃើញ -> Vector: [-0.00344256 -0.04034427 -0.00361456  0.05811671 -0.02082616]...
# Word: ផ្ទុក -> Vector: [0.09193765 0.05465265 0.04010325 0.14360154 0.00922115]...
# Word: មេរោគ -> Vector: [ 0.07845636 -0.01444783  0.00146271  0.10039832 -0.08200911]...
# Word: ករណី -> Vector: [-0.05647295  0.01683438 -0.0265009  -0.00170022 -0.05695137]...
# Word: ហៅថា -> Vector: [ 0.03376746 -0.00860548  0.04724325 -0.06122671 -0.0122154 ]...
# Word: ក្នុង -> Vector: [ 0.00331758 -0.03540234 -0.0066963  -0.00322061 -0.00039702]...
# Word: ករណី -> Vector: [-0.05647295  0.01683438 -0.0265009  -0.00170022 -0.05695137]...
# Word: ជន -> Vector: [ 0.05946155 -0.0749093  -0.13023719 -0.3021586   0.04605401]...
# Word: ឆ្លង -> Vector: [ 0.03519922 -0.00709001  0.00515401  0.10655373 -0.08541018]...
# Word: ខ្សែ -> Vector: [ 0.12155738 -0.00281707 -0.0625612   0.1179932  -0.01475345]...
# Word: ត្រៀម -> Vector: [ 0.03402746  0.12292007 -0.00117205 -0.02609382  0.02459265]...
# Word: ការពារ -> Vector: [0.03588165 0.01845887 0.01069522 0.02090171 0.02565231]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: ក្នុង -> Vector: [ 0.00331758 -0.03540234 -0.0066963  -0.00322061 -0.00039702]...
# Word: ករណី -> Vector: [-0.05647295  0.01683438 -0.0265009  -0.00170022 -0.05695137]...
# Word: នឹង -> Vector: [-0.01348948 -0.03600861  0.04667981 -0.01458256  0.01917716]...
# Word: នាំឲ្យ -> Vector: [-0.02438342  0.01170423  0.0105413  -0.0046031  -0.03365795]...
# Word: ការរាលដាល -> Vector: [-0.00240573 -0.00833084 -0.02312067  0.05133001 -0.02554387]...
# Word: មេរោគ -> Vector: [ 0.07845636 -0.01444783  0.00146271  0.10039832 -0.08200911]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: បើសិនជា -> Vector: [-0.06334738  0.01922954 -0.00330589 -0.00789224  0.01266484]...
# Word: ជន -> Vector: [ 0.05946155 -0.0749093  -0.13023719 -0.3021586   0.04605401]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: អនុវត្ត -> Vector: [-0.02039548 -0.02729918  0.00271643 -0.00847506 -0.01271585]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: ការដាក់ -> Vector: [ 0.02044666 -0.00778649 -0.00250299 -0.00830296  0.00099657]...
# Word: ឯង -> Vector: [-0.0085223  -0.11996096  0.06903144 -0.15961294 -0.06134675]...
# Word: ដាច់ដោយឡែក -> Vector: [-0.01029185 -0.0180534  -0.02084902 -0.02727997  0.01326502]...
# Word: ក្នុង -> Vector: [ 0.00331758 -0.03540234 -0.0066963  -0.00322061 -0.00039702]...
# Word: រយៈពេល -> Vector: [-0.00354148  0.02862719  0.01408264  0.00471839  0.00655422]...
# Word: ថ្ងៃ -> Vector: [ 0.00425566 -0.0162357  -0.00135446  0.00474433 -0.01356429]...
# Word: តាមដាន -> Vector: [ 0.06618685 -0.07934482 -0.01418721  0.04679122  0.01871854]...
# Word: ក្នុង -> Vector: [ 0.00331758 -0.03540234 -0.0066963  -0.00322061 -0.00039702]...
# Word: ចំណុច -> Vector: [-0.03341492 -0.01046169 -0.01226253  0.03275311 -0.05342869]...
# Word: សារសំខាន់ -> Vector: [ 0.05910027 -0.01164838  0.01309949  0.04609718 -0.0402784 ]...
# Word: ធ្វើដំណើរ -> Vector: [ 0.01661683  0.03220078  0.01864211 -0.02559964  0.01658083]...
# Word: ចូល -> Vector: [-0.02848471  0.01358267  0.02468962  0.0002034   0.06798841]...
# Word: ប្រទេស -> Vector: [ 0.0133411   0.01293716  0.00663447 -0.04537583 -0.01400372]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: ត្រូវតែ -> Vector: [ 0.00440897  0.00631027  0.00802637  0.0021175  -0.01337877]...
# Word: អនុវត្ត -> Vector: [-0.02039548 -0.02729918  0.00271643 -0.00847506 -0.01271585]...
# Word: ឲ្យបាន -> Vector: [ 0.00459343  0.00154004  0.01320049  0.03062005 -0.01407972]...
# Word: ការដាក់ -> Vector: [ 0.02044666 -0.00778649 -0.00250299 -0.00830296  0.00099657]...
# Word: ដោយឡែក -> Vector: [ 0.0142374  -0.04296588  0.01491532 -0.05974489 -0.00905461]...
# Word: ថ្ងៃ -> Vector: [ 0.00425566 -0.0162357  -0.00135446  0.00474433 -0.01356429]...
# Word: ទោះ -> Vector: [-0.14921038  0.04274574 -0.17614211  0.07363213 -0.06868532]...
# Word: ជា -> Vector: [ 0.0429856  -0.14815898  0.01771417 -0.02862751  0.01380449]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: ធ្វើតេស្ត -> Vector: [ 0.01574994 -0.05237399 -0.00872604  0.02760162 -0.01788941]...
# Word: រកឃើញ -> Vector: [ 0.00870357 -0.01067508  0.00607973  0.01969118 -0.02038949]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: មកដល់ -> Vector: [ 0.00845311  0.00364513 -0.0147155  -0.0023592   0.03743618]...
# Word: ព្រលានយន្តហោះ -> Vector: [-0.00238097 -0.00356162  0.0084822   0.02480515 -0.00695193]...
# Word: កត្តា -> Vector: [ 0.02031308 -0.02933812 -0.08689989  0.04491511  0.00763751]...
# Word: ហានិភ័យ -> Vector: [-0.00478893 -0.01658219  0.02576025  0.04425052  0.06557082]...
# Word: ប្រជាជន -> Vector: [ 0.00974695 -0.00742508 -0.00670336 -0.05192851 -0.00032723]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: ហាក់ដូចជា -> Vector: [-0.0366983  -0.02919079 -0.02404462 -0.02010278  0.02712435]...
# Word: អនុវត្ត -> Vector: [-0.02039548 -0.02729918  0.00271643 -0.00847506 -0.01271585]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: គោលការណ៍ -> Vector: [-0.01762865 -0.00571741  0.01617585  0.01219986 -0.01223897]...
# Word: គម្លាត -> Vector: [-0.0571488  -0.03392174 -0.02289335  0.01760477  0.00364192]...
# Word: សង្គម -> Vector: [ 0.00150067 -0.02312873 -0.02446991 -0.00627489 -0.02728902]...
# Word: ម៉ែត្រ -> Vector: [-0.06111104  0.00383325 -0.05284179  0.04897216 -0.01689847]...
# Word: ការគោរព -> Vector: [ 0.01622486  0.01463531  0.0385549   0.07210519 -0.03258544]...
# Word: គោលការណ៍ -> Vector: [-0.01762865 -0.00571741  0.01617585  0.01219986 -0.01223897]...
# Word: កាត់បន្ថយ -> Vector: [-0.01631166  0.02448904  0.00606153  0.00796538  0.02788046]...
# Word: ការចម្លង -> Vector: [ 0.00489964 -0.01828791 -0.00376666  0.03079791  0.02819238]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: ទៅកាន់ -> Vector: [-0.01586091  0.03152791  0.02439408 -0.04917064  0.04931036]...
# Word: អ្នកដទៃ -> Vector: [-0.02272849  0.01704979  0.04610933  0.02564016 -0.00132689]...
# Word: សហគមន៍ -> Vector: [ 0.0232792  -0.02307178  0.00730944 -0.02068416 -0.00277588]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: ប្រជាជន -> Vector: [ 0.00974695 -0.00742508 -0.00670336 -0.05192851 -0.00032723]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: ជាច្រើន -> Vector: [-0.00561647 -0.00525619 -0.01304061 -0.04688359  0.00115179]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: ត្រៀម -> Vector: [ 0.03402746  0.12292007 -0.00117205 -0.02609382  0.02459265]...
# Word: ការធ្វើដំណើរកម្សាន្ត -> Vector: [ 0.01241052 -0.00691604  0.00010659  0.01644991 -0.00201184]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: ថ្ងៃទី -> Vector: [ 0.036052    0.00134358  0.01997465 -0.01750254 -0.0384452 ]...
# Word: ថ្ងៃទី -> Vector: [ 0.036052    0.00134358  0.01997465 -0.01750254 -0.0384452 ]...
# Word: ខែសីហា -> Vector: [-0.01383933 -0.00347107  0.01652075  0.04917513  0.04534669]...
# Word: នាំឲ្យ -> Vector: [-0.02438342  0.01170423  0.0105413  -0.0046031  -0.03365795]...
# Word: ការព្រួយបារម្ភ -> Vector: [ 0.00034846  0.00595834  0.01187229  0.00984057 -0.01089586]...
# Word: ខ្លាំង -> Vector: [0.00135131 0.00682149 0.00612685 0.02931699 0.02089163]...
# Word: បើសិនជា -> Vector: [-0.06334738  0.01922954 -0.00330589 -0.00789224  0.01266484]...
# Word: គោលការណ៍ -> Vector: [-0.01762865 -0.00571741  0.01617585  0.01219986 -0.01223897]...
# Word: គម្លាត -> Vector: [-0.0571488  -0.03392174 -0.02289335  0.01760477  0.00364192]...
# Word: សង្គម -> Vector: [ 0.00150067 -0.02312873 -0.02446991 -0.00627489 -0.02728902]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: អនុវត្ត -> Vector: [-0.02039548 -0.02729918  0.00271643 -0.00847506 -0.01271585]...
# Word: ឲ្យបាន -> Vector: [ 0.00459343  0.00154004  0.01320049  0.03062005 -0.01407972]...
# Word: ត្រឹមត្រូវ -> Vector: [ 0.00790816 -0.02339448  0.01736912  0.03497068 -0.0075844 ]...
# Word: កត្តា -> Vector: [ 0.02031308 -0.02933812 -0.08689989  0.04491511  0.00763751]...
# Word: ហានិភ័យ -> Vector: [-0.00478893 -0.01658219  0.02576025  0.04425052  0.06557082]...
# Word: ប្រជាជន -> Vector: [ 0.00974695 -0.00742508 -0.00670336 -0.05192851 -0.00032723]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: សូវ -> Vector: [ 0.03589731 -0.08030409 -0.13878463  0.07929698  0.03816983]...
# Word: ឃើញ -> Vector: [-0.00344256 -0.04034427 -0.00361456  0.05811671 -0.02082616]...
# Word: ពាក់ -> Vector: [ 0.03534241  0.0470068  -0.00087783 -0.01926613  0.01592137]...
# Word: ម៉ាស -> Vector: [ 0.00783865 -0.02384455 -0.03775188 -0.12462441 -0.09782705]...
# Word: ដូច -> Vector: [ 0.02043152 -0.08907513 -0.01724196 -0.04211538  0.02004952]...
# Word: មុន -> Vector: [ 0.00027211 -0.03921135  0.04225482  0.06388214 -0.01478048]...
# Word: ការពាក់ -> Vector: [ 0.01290782 -0.00815086  0.00305796  0.01383726 -0.01490265]...
# Word: ម៉ាស -> Vector: [ 0.00783865 -0.02384455 -0.03775188 -0.12462441 -0.09782705]...
# Word: សារៈសំខាន់ -> Vector: [ 0.02036724  0.01132806  0.01782169 -0.01017566  0.01689921]...
# Word: ការទប់ស្កាត់ -> Vector: [0.01409151 0.02190454 0.00276557 0.00925554 0.00220164]...
# Word: ការឆ្លង -> Vector: [ 0.01795284 -0.00442468  0.01718615  0.01881581 -0.00593753]...
# Word: ចម្លង -> Vector: [ 0.0259374  -0.03586432  0.01509798  0.14019638  0.00934434]...
# Word: មេរោគ -> Vector: [ 0.07845636 -0.01444783  0.00146271  0.10039832 -0.08200911]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: ទីក្រុង -> Vector: [ 0.01557681 -0.02749022  0.02470703 -0.04680833  0.01169885]...
# Word: ហុងកុង -> Vector: [-0.00089516 -0.08879095 -0.03227291 -0.05641726  0.0238303 ]...
# Word: បាន -> Vector: [-0.00208958 -0.01692417  0.0137838  -0.01388112  0.01524533]...
# Word: គោលការណ៍ -> Vector: [-0.01762865 -0.00571741  0.01617585  0.01219986 -0.01223897]...
# Word: ឲ្យ -> Vector: [-0.01355013 -0.01519408 -0.00186673  0.02926468 -0.00065203]...
# Word: ប្រជាជន -> Vector: [ 0.00974695 -0.00742508 -0.00670336 -0.05192851 -0.00032723]...
# Word: ពាក់ -> Vector: [ 0.03534241  0.0470068  -0.00087783 -0.01926613  0.01592137]...
# Word: ម៉ាស -> Vector: [ 0.00783865 -0.02384455 -0.03775188 -0.12462441 -0.09782705]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: សាធារណៈ -> Vector: [-0.0341709  -0.01646556 -0.00094555  0.0442635   0.04296622]...
# Word: ជា -> Vector: [ 0.0429856  -0.14815898  0.01771417 -0.02862751  0.01380449]...
# Word: វិធានការ -> Vector: [-0.0566525   0.05700725 -0.03002269  0.02857593 -0.04020689]...
# Word: ការទប់ស្កាត់ -> Vector: [0.01409151 0.02190454 0.00276557 0.00925554 0.00220164]...
# Word: មេរោគ -> Vector: [ 0.07845636 -0.01444783  0.00146271  0.10039832 -0.08200911]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: បើសិនជា -> Vector: [-0.06334738  0.01922954 -0.00330589 -0.00789224  0.01266484]...
# Word: ចៀសវាង -> Vector: [-0.09086837 -0.00533627 -0.00527491  0.02791876  0.00888681]...
# Word: ការចម្លង -> Vector: [ 0.00489964 -0.01828791 -0.00376666  0.03079791  0.02819238]...
# Word: កូវីដ -> Vector: [-3.6070496e-04 -2.0839243e-04  4.0976651e-05 -8.5223204e-05
#  -5.0289149e-05]...
# Word: ចូល -> Vector: [-0.02848471  0.01358267  0.02468962  0.0002034   0.06798841]...
# Word: សហគមន៍ -> Vector: [ 0.0232792  -0.02307178  0.00730944 -0.02068416 -0.00277588]...
# Word: ប្រជាជន -> Vector: [ 0.00974695 -0.00742508 -0.00670336 -0.05192851 -0.00032723]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: អ្នកធ្វើដំណើរ -> Vector: [ 0.01919977 -0.01155374 -0.00366519  0.0109041  -0.00985369]...
# Word: ចូល -> Vector: [-0.02848471  0.01358267  0.02468962  0.0002034   0.06798841]...
# Word: ប្រទេស -> Vector: [ 0.0133411   0.01293716  0.00663447 -0.04537583 -0.01400372]...
# Word: កម្ពុជា -> Vector: [ 0.00321709  0.01240032 -0.00574631 -0.01219825 -0.00409323]...
# Word: មិន -> Vector: [-0.04971214 -0.02930917  0.01643053  0.03986594 -0.0139435 ]...
# Word: ប្រហែស -> Vector: [-0.03345599  0.05267933  0.04053002  0.08429828  0.00405834]...
# Word: ទន្ទឹម -> Vector: [ 0.02315152 -0.05925209 -0.01998337  0.01163759  0.00672016]...
# Word: ត្រូវតែ -> Vector: [ 0.00440897  0.00631027  0.00802637  0.0021175  -0.01337877]...
# Word: រស់ -> Vector: [ 0.08286615 -0.0778763  -0.02047594  0.06469156 -0.05687692]...
# Word: នៅ -> Vector: [ 0.01528219 -0.11528249 -0.0119004  -0.05559783 -0.05907962]...
# Word: គន្លង -> Vector: [ 0.01367316 -0.01892994 -0.00286612  0.07083007 -0.03388325]...
# Word: បែប -> Vector: [ 0.00561367 -0.07549343 -0.0609184   0.00297027  0.00193196]...
# Word: ប្រកបដោយ -> Vector: [ 0.0155818  -0.01905824  0.01637276  0.01603835 -0.00157058]...
# Word: អនាម័យ -> Vector: [-0.02736541 -0.0481797  -0.07061617  0.14789034 -0.03529079]...
# Word: លាង -> Vector: [ 0.00912491 -0.19077113 -0.00262732  0.15146974  0.00650277]...
# Word: សម្អាត -> Vector: [ 0.05373869 -0.02318579  0.01056631  0.06529358 -0.02747936]...
# Word: ដៃ -> Vector: [ 0.15425514 -0.02404347  0.02188811  0.03946651 -0.03533217]...
# Word: គិត -> Vector: [-0.03420072 -0.13105711  0.06048586  0.06789787 -0.02675577]...
# Word: អាចនឹង -> Vector: [-0.00245684 -0.02277157 -0.01430559  0.02505141 -0.01870622]...
# Word: ប៉ះពាល់ -> Vector: [ 0.04319679  0.00901727 -0.03095291  0.03625945 -0.01786169]...
# Word: ជាមួយ -> Vector: [-0.0054327  -0.05094552  0.01767656 -0.03128471  0.01256001]...
# Word: ចម្លង -> Vector: [ 0.0259374  -0.03586432  0.01509798  0.14019638  0.00934434]...
# Word: មេរោគ -> Vector: [ 0.07845636 -0.01444783  0.00146271  0.10039832 -0.08200911]...
# Word: អ -> Vector: [ 0.14738254 -0.01508896  0.15553637  0.05529615  0.00671512]...
# Word: សួស្តី -> Vector: [-0.06494144  0.03658145  0.03918764  0.0295424  -0.01903915]...
#
# Summary:
# Total tokens: 279
# Tokens with embeddings: 279
# Tokens missing embeddings: 0
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6036 (\N{KHMER LETTER BA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6098 (\N{KHMER SIGN COENG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6042 (\N{KHMER LETTER RO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6048 (\N{KHMER LETTER HA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6082 (\N{KHMER VOWEL SIGN AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6047 (\N{KHMER LETTER SA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6034 (\N{KHMER LETTER THO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6044 (\N{KHMER LETTER VO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6078 (\N{KHMER VOWEL SIGN OE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6066 (\N{KHMER INDEPENDENT VOWEL QOO TYPE TWO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6041 (\N{KHMER LETTER YO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6016 (\N{KHMER LETTER KA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6040 (\N{KHMER LETTER MO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6038 (\N{KHMER LETTER PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6075 (\N{KHMER VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6023 (\N{KHMER LETTER CO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6070 (\N{KHMER VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6018 (\N{KHMER LETTER KO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6084 (\N{KHMER VOWEL SIGN OO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6087 (\N{KHMER SIGN REAHMUK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6032 (\N{KHMER LETTER THA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6035 (\N{KHMER LETTER NO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6091 (\N{KHMER SIGN BANTOC}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6022 (\N{KHMER LETTER CHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6043 (\N{KHMER LETTER LO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6020 (\N{KHMER LETTER NGO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6026 (\N{KHMER LETTER DA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6076 (\N{KHMER VOWEL SIGN UU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6072 (\N{KHMER VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6086 (\N{KHMER SIGN NIKAHIT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6030 (\N{KHMER LETTER NNO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6019 (\N{KHMER LETTER KHO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6025 (\N{KHMER LETTER NYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6085 (\N{KHMER VOWEL SIGN AU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6017 (\N{KHMER LETTER KHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6077 (\N{KHMER VOWEL SIGN UA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6039 (\N{KHMER LETTER PHO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6033 (\N{KHMER LETTER TO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6050 (\N{KHMER LETTER QA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6021 (\N{KHMER LETTER CA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6073 (\N{KHMER VOWEL SIGN Y}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6093 (\N{KHMER SIGN TOANDAKHIAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6081 (\N{KHMER VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6071 (\N{KHMER VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6031 (\N{KHMER LETTER TA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6096 (\N{KHMER SIGN SAMYOK SANNYA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6024 (\N{KHMER LETTER CHO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6088 (\N{KHMER SIGN YUUKALEAPINTU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6083 (\N{KHMER VOWEL SIGN AI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6037 (\N{KHMER LETTER PHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6049 (\N{KHMER LETTER LA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6027 (\N{KHMER LETTER TTHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6089 (\N{KHMER SIGN MUUSIKATOAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6080 (\N{KHMER VOWEL SIGN IE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:123: UserWarning: Glyph 6063 (\N{KHMER INDEPENDENT VOWEL QE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6036 (\N{KHMER LETTER BA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6098 (\N{KHMER SIGN COENG}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6042 (\N{KHMER LETTER RO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6048 (\N{KHMER LETTER HA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6082 (\N{KHMER VOWEL SIGN AE}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6047 (\N{KHMER LETTER SA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6034 (\N{KHMER LETTER THO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6044 (\N{KHMER LETTER VO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6078 (\N{KHMER VOWEL SIGN OE}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6066 (\N{KHMER INDEPENDENT VOWEL QOO TYPE TWO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6041 (\N{KHMER LETTER YO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6016 (\N{KHMER LETTER KA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6040 (\N{KHMER LETTER MO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6038 (\N{KHMER LETTER PO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6075 (\N{KHMER VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6023 (\N{KHMER LETTER CO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6070 (\N{KHMER VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6018 (\N{KHMER LETTER KO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6084 (\N{KHMER VOWEL SIGN OO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6087 (\N{KHMER SIGN REAHMUK}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6032 (\N{KHMER LETTER THA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6035 (\N{KHMER LETTER NO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6091 (\N{KHMER SIGN BANTOC}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6022 (\N{KHMER LETTER CHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6043 (\N{KHMER LETTER LO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6020 (\N{KHMER LETTER NGO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6026 (\N{KHMER LETTER DA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6076 (\N{KHMER VOWEL SIGN UU}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6072 (\N{KHMER VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6086 (\N{KHMER SIGN NIKAHIT}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6030 (\N{KHMER LETTER NNO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6019 (\N{KHMER LETTER KHO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6025 (\N{KHMER LETTER NYO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6085 (\N{KHMER VOWEL SIGN AU}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6017 (\N{KHMER LETTER KHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6077 (\N{KHMER VOWEL SIGN UA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6039 (\N{KHMER LETTER PHO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6033 (\N{KHMER LETTER TO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6050 (\N{KHMER LETTER QA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6021 (\N{KHMER LETTER CA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6073 (\N{KHMER VOWEL SIGN Y}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6093 (\N{KHMER SIGN TOANDAKHIAT}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6081 (\N{KHMER VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6071 (\N{KHMER VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6031 (\N{KHMER LETTER TA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6096 (\N{KHMER SIGN SAMYOK SANNYA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6024 (\N{KHMER LETTER CHO}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6088 (\N{KHMER SIGN YUUKALEAPINTU}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6083 (\N{KHMER VOWEL SIGN AI}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6037 (\N{KHMER LETTER PHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6049 (\N{KHMER LETTER LA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6027 (\N{KHMER LETTER TTHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6089 (\N{KHMER SIGN MUUSIKATOAN}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6080 (\N{KHMER VOWEL SIGN IE}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# /var/folders/9n/ttnnmpy11wb3xzbvs4djr1yr0000gn/T/ipykernel_7385/220772821.py:124: UserWarning: Glyph 6063 (\N{KHMER INDEPENDENT VOWEL QE}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_path)
# Word embeddings visualization saved to /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/word_embeddings_tsne.png
# Embedding norms plot saved to /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/embedding_norms.png
# Word embeddings saved to /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/word_embeddings.json
#
# Loaded 15000 documents with embeddings.
#
# All words from the first document:
# ['ប្រហែស', 'ធ្វើឲ្យ', 'កម្ពុជា', 'គ្រោះថ្នាក់', 'ឆ្លង', 'រាលដាល', 'កូវីដ', 'កូវីដ', 'កំណើន', 'ការរកឃើញ', 'កូវីដ', 'នៅ', 'ខែកក្កដា', 'កន្លងមក', 'បាន', 'ធ្វើឲ្យ', 'ការព្រួយបារម្ភ', 'ខ្លាំង', 'លទ្ធភាព', 'អាចនឹង', 'ការរាលដាល', 'ជា', 'សហគមន៍', 'នៅ', 'ប្រទេស', 'កម្ពុជា', 'មកដល់', 'ពេលនេះ', 'មិន', 'កើតមាន', 'ក្រសូង', 'សុខាភិបាល', 'បាន', 'ព្រមាន', 'ការរាលដាល', 'ជា', 'សហគមន៍', 'មិន', 'ប្រាកដ', 'ជា', 'មិន', 'កើតមាន', 'នៅ', 'ប្រទេស', 'កម្ពុជា', 'ជំរុញ', 'ឲ្យ', 'ប្រជាជន', 'កម្ពុជា', 'បង្កើន', 'ការប្រុងប្រយ័ត្ន', 'ពិសេស', 'ឈប់', 'សម្រាក', 'រយៈពេល', 'ប្រាំ', 'ថ្ងៃ', 'ថ្ងៃទី', 'ខែសីហា', 'គិត', 'ប្រជាជន', 'ជាច្រើន', 'ធ្វើដំណើរកម្សាន្ត', 'ក្នុង', 'ប្រទេស', 'ការព្រួយបារម្ភ', 'លទ្ធភាព', 'ការរាលដាល', 'ជា', 'សហគមន៍', 'កើតមាន', 'នៅ', 'ផ្ទុក', 'មេរោគ', 'កូវីដ', 'នៅ', 'កម្ពុជា', 'រកឃើញ', 'កើនឡើង', 'នាក់', 'កត្តា', 'នាំ', 'ការរាលដាល', 'ជា', 'សហគមន៍', 'រហូតម', 'ពេលនេះ', 'ប្រាកដ', 'ករណី', 'កូវីដ', 'ទាក់ទង', 'ការនាំចូល', 'កម្ពុជា', 'បើក', 'ការហោះហើរ', 'ទូលាយ', 'ចូល', 'ប្រទេស', 'កម្ពុជា', 'សេដ្ឋកិច្ច', 'កត្តា', 'គួរឲ្យ', 'ព្រួយបារម្ភ', 'ករណី', 'កើតមាន', 'បាន', 'ផ្ទុក', 'មេរោគ', 'កូវីដ', 'បាន', 'មកដល់', 'ព្រលានយន្តហោះ', 'បាន', 'ធ្វើតេស្ត', 'ប៉ុន្តែ', 'រក', 'មិន', 'ឃើញ', 'ផ្ទុក', 'មេរោគ', 'ករណី', 'ហៅថា', 'ក្នុង', 'ករណី', 'ជន', 'ឆ្លង', 'ខ្សែ', 'ត្រៀម', 'ការពារ', 'កម្ពុជា', 'ក្នុង', 'ករណី', 'នឹង', 'នាំឲ្យ', 'ការរាលដាល', 'មេរោគ', 'កូវីដ', 'បើសិនជា', 'ជន', 'មិន', 'អនុវត្ត', 'បាន', 'ការដាក់', 'ឯង', 'ដាច់ដោយឡែក', 'ក្នុង', 'រយៈពេល', 'ថ្ងៃ', 'តាមដាន', 'ក្នុង', 'ចំណុច', 'សារសំខាន់', 'ធ្វើដំណើរ', 'ចូល', 'ប្រទេស', 'កម្ពុជា', 'ត្រូវតែ', 'អនុវត្ត', 'ឲ្យបាន', 'ការដាក់', 'ដោយឡែក', 'ថ្ងៃ', 'ទោះ', 'ជា', 'មិន', 'ធ្វើតេស្ត', 'រកឃើញ', 'កូវីដ', 'មកដល់', 'ព្រលានយន្តហោះ', 'កត្តា', 'ហានិភ័យ', 'ប្រជាជន', 'កម្ពុជា', 'ហាក់ដូចជា', 'អនុវត្ត', 'មិន', 'បាន', 'គោលការណ៍', 'គម្លាត', 'សង្គម', 'ម៉ែត្រ', 'ការគោរព', 'គោលការណ៍', 'កាត់បន្ថយ', 'ការចម្លង', 'កូវីដ', 'ទៅកាន់', 'អ្នកដទៃ', 'សហគមន៍', 'នៅ', 'ប្រជាជន', 'កម្ពុជា', 'ជាច្រើន', 'បាន', 'ត្រៀម', 'ការធ្វើដំណើរកម្សាន្ត', 'នៅ', 'ថ្ងៃទី', 'ថ្ងៃទី', 'ខែសីហា', 'នាំឲ្យ', 'ការព្រួយបារម្ភ', 'ខ្លាំង', 'បើសិនជា', 'គោលការណ៍', 'គម្លាត', 'សង្គម', 'មិន', 'អនុវត្ត', 'ឲ្យបាន', 'ត្រឹមត្រូវ', 'កត្តា', 'ហានិភ័យ', 'ប្រជាជន', 'កម្ពុជា', 'មិន', 'សូវ', 'ឃើញ', 'ពាក់', 'ម៉ាស', 'ដូច', 'មុន', 'ការពាក់', 'ម៉ាស', 'សារៈសំខាន់', 'ការទប់ស្កាត់', 'ការឆ្លង', 'ចម្លង', 'មេរោគ', 'កូវីដ', 'ទីក្រុង', 'ហុងកុង', 'បាន', 'គោលការណ៍', 'ឲ្យ', 'ប្រជាជន', 'ពាក់', 'ម៉ាស', 'នៅ', 'សាធារណៈ', 'ជា', 'វិធានការ', 'ការទប់ស្កាត់', 'មេរោគ', 'កូវីដ', 'បើសិនជា', 'ចៀសវាង', 'ការចម្លង', 'កូវីដ', 'ចូល', 'សហគមន៍', 'ប្រជាជន', 'កម្ពុជា', 'អ្នកធ្វើដំណើរ', 'ចូល', 'ប្រទេស', 'កម្ពុជា', 'មិន', 'ប្រហែស', 'ទន្ទឹម', 'ត្រូវតែ', 'រស់', 'នៅ', 'គន្លង', 'បែប', 'ប្រកបដោយ', 'អនាម័យ', 'លាង', 'សម្អាត', 'ដៃ', 'គិត', 'អាចនឹង', 'ប៉ះពាល់', 'ជាមួយ', 'ចម្លង', 'មេរោគ', 'អ', 'សួស្តី']
# Saved: /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/document_tsne_by_category.png
#
# Document embeddings saved to /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/embeddings.npy
# Labels saved to /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/labels.npy
# Document IDs saved to /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/doc_ids.npy
# Word embeddings per document saved to /Users/socheata/Documents/FYP-Khmer-Classification/FastText_Features/word_embeddings_per_doc.pkl
